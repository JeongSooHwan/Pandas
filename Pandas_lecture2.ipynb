# %% [markdown]
# # 파일에서 데이터 불러오기

# %%
import pandas as pd

# %%
df = pd.read_csv('pandas_data/friend_list.csv')

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brain   45    manager
# 5  Chris   25     intern

# %%
df.head()
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brain   45    manager

# %%
dftxt = pd.read_csv('pandas_data/friend_list_tab.txt')

# %%
dftxt
# Out:
#          Name\tAge\tJob
# 0     John\t20\tstudent
# 1  Jenny\t30\tdeveloper
# 2    Jenny\t30\tteacher
# 3     Nate\t30\tdentist
# 4    Julia\t40\tdentist
# 5    Brain\t40\tmanager
# 6     Chris\t25\tintern

# %%
dftxt = pd.read_csv('pandas_data/friend_list_tab.txt', delimiter = '\t')

# %%
dftxt
# Out:
#     Name  Age        Job
# 0   John   20    student
# 1  Jenny   30  developer
# 2  Jenny   30    teacher
# 3   Nate   30    dentist
# 4  Julia   40    dentist
# 5  Brain   40    manager
# 6  Chris   25     intern

# %%
df = pd.read_csv('pandas_data/friend_list_no_head.csv', header = None)

# %%
df
# Out:
#        0   1          2
# 0   John  20    student
# 1  Jenny  30  developer
# 2   Nate  30    teacher
# 3  Julia  40    dentist
# 4  Brain  45    manager
# 5  Chris  25     intern

# %%
df.columns = ['name', 'age', 'job']

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brain   45    manager
# 5  Chris   25     intern

# %%
df = pd.read_csv('pandas_data/friend_list_no_head.csv', header = None, names = ['Name', 'Age', 'Job'])

# %%
df
# Out:
#     Name  Age        Job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brain   45    manager
# 5  Chris   25     intern
